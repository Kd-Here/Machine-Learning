# %%
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
from lab_utils_common import  plot_data, sigmoid, dlc
plt.style.use('./deeplearning.mplstyle')

# %%
X_train = np.array([[0.5, 1.5], [1,1], [1.5, 0.5], [3, 0.5], [2, 2], [1, 2.5]])  #(m,n)
y_train = np.array([0, 0, 0, 1, 1, 1])                                           #(m,)

# %%
fig,ax = plt.subplots(1,1)
plot_data(X_train, y_train, ax)

# Set both axes to be from 0-4
ax.axis([0, 4, 0, 4])

ax.set_ylabel('$x_1$', fontsize=12)
ax.set_xlabel('$x_0$', fontsize=12)
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
plt.clf()
X = list(range(2,16,2))
Y = list(range(1,8))

# %%
fig, axs = plt.subplots(1,1,figsize=(4,4))
fig.suptitle('Vertically stacked subplots')
axs.scatter(X, Y)
axs.plot(X, Y)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x0 = np.arange(0,6)

# Plot the two decision boundaries
x1 = 3 - x0
x1_other = 4 - x0


fig, axx = plt.subplots(1,1,figsize=(4,4))
print(X_train)
print(y_train)



for i in range(6):
    if y_train[i] == 0:
        axx.scatter(X_train[i][0],X_train[i][1],marker="o",c="red",s=80,label="X")

    else:
        axx.scatter(X_train[i][0],X_train[i][1],marker="*",c="blue",s=80,label="Y")


axx.plot(x0,x1, c=dlc["dlblue"])
axx.plot(x1_other,x0*x0,c=dlc["dlmagenta"])
plt.legend()
axx.axis([0, 4, 0, 4])
axx.set_ylabel('$x_1$', fontsize=12)
axx.set_xlabel('$x_0$', fontsize=12)


axx.figure.canvas.toolbar_visible = False
axx.figure.canvas.header_visible = False
axx.figure.canvas.footer_visible = False

plt.title("Logistic regression plot for 2features graph")


plt.show()
# Out:
# [[0.5 1.5]
#  [1.  1. ]
#  [1.5 0.5]
#  [3.  0.5]
#  [2.  2. ]
#  [1.  2.5]]
# [0 0 0 1 1 1]
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …

# %%
import matplotlib.pyplot as plt

# Choose values between 0 and 6
x0 = np.arange(0,6)

# Plot the two decision boundaries
x1 = 3 - x0
x1_other = 4 - x0

fig,ax = plt.subplots(1, 1, figsize=(4,4))
# Plot the decision boundary
ax.plot(x0,x1, c=dlc["dlblue"], label="$b$=-3")
ax.plot(x0,x1_other, c=dlc["dlmagenta"], label="$b$=-4")
ax.axis([0, 4, 0, 4])

# Plot the original data
plot_data(X_train,y_train,ax)
ax.axis([0, 4, 0, 4])
ax.set_ylabel('$x_1$', fontsize=12)
ax.set_xlabel('$x_0$', fontsize=12)
plt.legend()
plt.title("Decision Boundary")
plt.show()
# Out:
# Canvas(footer_visible=False, header_visible=False, toolbar=Toolbar(toolitems=[('Home', 'Reset original view', …
